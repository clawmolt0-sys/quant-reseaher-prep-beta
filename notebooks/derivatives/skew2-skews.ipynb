# %%
from typing import List
import pandas as pd

import solpy as sol

# %% [markdown]
# # Skew Comparison
#
# 1. Take the skew from the intro, copy the code into a function, and generate a flat 15% vol skew.
# 2. Visual both skews on a single plot
# 3. Find the strike (every $25) with the most edge if we could trade the flat skew.

# %% [markdown]
# ## 1. Generate Two Skews
#
# Take the skew from the intro, copy the code into a function, and generate a flat 15% vol skew.

# %% [markdown]
# ## 2. Plot Skews

# %% [markdown]
# ## 3. Find Max Edge

# %% [markdown]
# ## 4. Find the PDF given the original skew

# %% [markdown]
# ## 5. Bad Skews
#
# Use previously defined greeks to simulate what happens to the skew if the 2000 call were to increase in price by $1.5

# %% [markdown]
# # Extra Time Exercise
#
# Using webworm, tickster or faking value, define a set of call/put bid and ask values for a single expiry and fit a sol skew to it.
