# %%
# Boilerplate imports

# %load_ext autoreload
# %autoreload 2
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %% [markdown]
# # Collaborative Exercise

# %% [markdown]
# ## 1. SVI
#
# Implement Gatheral's SVI model, as defined in section 3.1 of this paper: https://arxiv.org/pdf/1204.0646.pdf
#
# This is an example of a parametric model, similar to S3.
#
# Fit the JPM data we used in the lecture.
#
# - How does the SVI fit compare to the S3 fit?
# - What weighting scheme would you use, and why?
# - How would you quantify the uncertainty in the fit result?
#
# Note:
#
# The columns in the two files are:
#
# unddata:
#
#         und	- underlying, eg JPM
#         term - expiration in format YYYYMMDD_HHMM
#         f - forward price
#         ct - calendar time
#         vt - volatility time
#         atfvol - at the forawrd vol from fit
#         rollrate - roll rate
#         boxrate	- box rate
#         ubpx - underlying bid price
#         uapx - underlying ask price
#         ubsz - underlying bid size
#         uasz - underlying ask size
#         (all market prices and sizes refer to top of book levels.)
#
# optdata:
#
#         und	- underlying, eg JPM
#         term - expiration in format YYYYMMDD_HHMM
#         kpx	- strike price
#         cbiv - IV of call bid if calculable else nan
#         caiv - IV of call ask if calculable els nan
#         cmiv - size-weighted mid of call bid and ask IVs
#         cbpx - call bid price
#         capx - call ask price
#         cbsz - call bid size
#         casz - call ask size
#         cdelta - call BS delta
#         cvega - call BS vega
#         (plus same columns with c replaced by p for put quantities)

# %% [markdown]
# ## 2. Term Structure
#
# Using the 3 day sample of data provided in JPM_vsum.csv, plot the term structure of at-the-money-forward vol.  Overlay several snapshots.
#
# - What features of the term structure appear to be durable?   Are there noisy features?
# - What factors do you think may contribute to explain this term structure?

# %% [markdown]
# ## 3.  Stability
#
# Using the data provided in the "calstrike" CSV file (main_overview_jpm_calstrike.csv), fit each term in each snapshot with a method of your choice.
#
#
#
# - Plot time series summarizing your fits
# - Comment on the stability (or lack thereof!) of the fits.
# - Did you encounter any technical issues?   If so, discuss and share approaches to resolving them.
